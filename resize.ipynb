# %%
import os
from PIL import Image

# Paths
input_folder = "org"     # Replace with your folder name
output_folder = "resize_train_org"  # This will be created if it doesn't exist

# Create output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# Desired size
target_size = (1024, 296)


# Supported image formats
valid_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff')

# Process each image in the folder
for filename in os.listdir(input_folder):
    if filename.lower().endswith(valid_extensions):
        input_path = os.path.join(input_folder, filename)
        output_path = os.path.join(output_folder, filename)

        with Image.open(input_path) as img:
            resized_img = img.resize(target_size, Image.Resampling.LANCZOS)
            resized_img.save(output_path)
            print(f"Resized and saved: {output_path}")

print("Done resizing all images.")
# Out:
# Resized and saved: resize_train_org\org_ecg_100_100.png
# Resized and saved: resize_train_org\org_ecg_100_1000.png
# Resized and saved: resize_train_org\org_ecg_100_1010.png
# Resized and saved: resize_train_org\org_ecg_100_1020.png
# Resized and saved: resize_train_org\org_ecg_100_1030.png
# Resized and saved: resize_train_org\org_ecg_100_1040.png
# Resized and saved: resize_train_org\org_ecg_100_1050.png
# Resized and saved: resize_train_org\org_ecg_100_1060.png
# Resized and saved: resize_train_org\org_ecg_100_1070.png
# Resized and saved: resize_train_org\org_ecg_100_1080.png
# Resized and saved: resize_train_org\org_ecg_100_1090.png
# Resized and saved: resize_train_org\org_ecg_100_110.png
# Resized and saved: resize_train_org\org_ecg_100_1100.png
# Resized and saved: resize_train_org\org_ecg_100_1110.png
# Resized and saved: resize_train_org\org_ecg_100_1120.png
# Resized and saved: resize_train_org\org_ecg_100_1130.png
# Resized and saved: resize_train_org\org_ecg_100_1140.png
# Resized and saved: resize_train_org\org_ecg_100_1150.png
# Resized and saved: resize_train_org\org_ecg_100_1160.png
# Resized and saved: resize_train_org\org_ecg_100_1170.png
# Resized and saved: resize_train_org\org_ecg_100_1180.png
# Resized and saved: resize_train_org\org_ecg_100_1190.png
# Resized and saved: resize_train_org\org_ecg_100_120.png
# Resized and saved: resize_train_org\org_ecg_100_1200.png
# Resized and saved: resize_train_org\org_ecg_100_1210.png
# Resized and saved: resize_train_org\org_ecg_100_1220.png
# Resized and saved: resize_train_org\org_ecg_100_1230.png
# Resized and saved: resize_train_org\org_ecg_100_1240.png
# Resized and saved: resize_train_org\org_ecg_100_1250.png
# Resized and saved: resize_train_org\org_ecg_100_1260.png
# Resized and saved: resize_train_org\org_ecg_100_1270.png
# Resized and saved: resize_train_org\org_ecg_100_1280.png
# Resized and saved: resize_train_org\org_ecg_100_1290.png
# Resized and saved: resize_train_org\org_ecg_100_130.png
# Resized and saved: resize_train_org\org_ecg_100_1300.png
# Resized and saved: resize_train_org\org_ecg_100_1310.png
# Resized and saved: resize_train_org\org_ecg_100_1320.png
# Resized and saved: resize_train_org\org_ecg_100_1330.png
# Resized and saved: resize_train_org\org_ecg_100_1340.png
# Resized and saved: resize_train_org\org_ecg_100_1350.png
# Resized and saved: resize_train_org\org_ecg_100_1360.png
# Resized and saved: resize_train_org\org_ecg_100_1370.png
# Resized and saved: resize_train_org\org_ecg_100_1380.png
# Resized and saved: resize_train_org\org_ecg_100_1390.png
# Resized and saved: resize_train_org\org_ecg_100_140.png
# Resized and saved: resize_train_org\org_ecg_100_1400.png
# Resized and saved: resize_train_org\org_ecg_100_1410.png
# Resized and saved: resize_train_org\org_ecg_100_1420.png
# Resized and saved: resize_train_org\org_ecg_100_1430.png
# Resized and saved: resize_train_org\org_ecg_100_1440.png
# Resized and saved: resize_train_org\org_ecg_100_1450.png
# Resized and saved: resize_train_org\org_ecg_100_1460.png
# Resized and saved: resize_train_org\org_ecg_100_1470.png
# Resized and saved: resize_train_org\org_ecg_100_1480.png
# Resized and saved: resize_train_org\org_ecg_100_1490.png
# Resized and saved: resize_train_org\org_ecg_100_150.png
# Resized and saved: resize_train_org\org_ecg_100_1500.png
# Resized and saved: resize_train_org\org_ecg_100_1510.png
# Resized and saved: resize_train_org\org_ecg_100_1520.png
# Resized and saved: resize_train_org\org_ecg_100_1530.png
# Resized and saved: resize_train_org\org_ecg_100_1540.png
# Resized and saved: resize_train_org\org_ecg_100_1550.png
# Resized and saved: resize_train_org\org_ecg_100_1560.png
# Resized and saved: resize_train_org\org_ecg_100_1570.png
# Resized and saved: resize_train_org\org_ecg_100_1580.png
# Resized and saved: resize_train_org\org_ecg_100_1590.png
# Resized and saved: resize_train_org\org_ecg_100_160.png
# Resized and saved: resize_train_org\org_ecg_100_1600.png
# Resized and saved: resize_train_org\org_ecg_100_1610.png
# Resized and saved: resize_train_org\org_ecg_100_1620.png
# Resized and saved: resize_train_org\org_ecg_100_1630.png
# Resized and saved: resize_train_org\org_ecg_100_1640.png
# Resized and saved: resize_train_org\org_ecg_100_1650.png
# Resized and saved: resize_train_org\org_ecg_100_1660.png
# Resized and saved: resize_train_org\org_ecg_100_1670.png
# Resized and saved: resize_train_org\org_ecg_100_1680.png
# Resized and saved: resize_train_org\org_ecg_100_1690.png
# Resized and saved: resize_train_org\org_ecg_100_170.png
# Resized and saved: resize_train_org\org_ecg_100_1700.png
# Resized and saved: resize_train_org\org_ecg_100_1710.png
# Resized and saved: resize_train_org\org_ecg_100_1720.png
# Resized and saved: resize_train_org\org_ecg_100_1730.png
# Resized and saved: resize_train_org\org_ecg_100_1740.png
# Resized and saved: resize_train_org\org_ecg_100_1750.png
# Resized and saved: resize_train_org\org_ecg_100_1760.png
# Resized and saved: resize_train_org\org_ecg_100_1770.png
# Resized and saved: resize_train_org\org_ecg_100_1780.png
# Resized and saved: resize_train_org\org_ecg_100_1790.png
# Resized and saved: resize_train_org\org_ecg_100_180.png
# Resized and saved: resize_train_org\org_ecg_100_1800.png
# Resized and saved: resize_train_org\org_ecg_100_190.png
# Resized and saved: resize_train_org\org_ecg_100_20.png
# Resized and saved: resize_train_org\org_ecg_100_200.png
# Resized and saved: resize_train_org\org_ecg_100_210.png
# Resized and saved: resize_train_org\org_ecg_100_220.png
# Resized and saved: resize_train_org\org_ecg_100_230.png
# Resized and saved: resize_train_org\org_ecg_100_240.png
# Resized and saved: resize_train_org\org_ecg_100_250.png
# Resized and saved: resize_train_org\org_ecg_100_260.png
# Resized and saved: resize_train_org\org_ecg_100_270.png
# Resized and saved: resize_train_org\org_ecg_100_280.png
# Resized and saved: resize_train_org\org_ecg_100_290.png
# Resized and saved: resize_train_org\org_ecg_100_30.png
# Resized and saved: resize_train_org\org_ecg_100_300.png
# Resized and saved: resize_train_org\org_ecg_100_310.png
# Resized and saved: resize_train_org\org_ecg_100_320.png
# Resized and saved: resize_train_org\org_ecg_100_330.png
# Resized and saved: resize_train_org\org_ecg_100_340.png
# Resized and saved: resize_train_org\org_ecg_100_350.png
# Resized and saved: resize_train_org\org_ecg_100_360.png
# Resized and saved: resize_train_org\org_ecg_100_370.png
# Resized and saved: resize_train_org\org_ecg_100_380.png
# Resized and saved: resize_train_org\org_ecg_100_390.png
# Resized and saved: resize_train_org\org_ecg_100_40.png
# Resized and saved: resize_train_org\org_ecg_100_400.png
# Resized and saved: resize_train_org\org_ecg_100_410.png
# Resized and saved: resize_train_org\org_ecg_100_420.png
# Resized and saved: resize_train_org\org_ecg_100_430.png
# Resized and saved: resize_train_org\org_ecg_100_440.png
# Resized and saved: resize_train_org\org_ecg_100_450.png
# Resized and saved: resize_train_org\org_ecg_100_460.png
# Resized and saved: resize_train_org\org_ecg_100_470.png
# Resized and saved: resize_train_org\org_ecg_100_480.png
# Resized and saved: resize_train_org\org_ecg_100_490.png
# Resized and saved: resize_train_org\org_ecg_100_50.png
# Resized and saved: resize_train_org\org_ecg_100_500.png
# Resized and saved: resize_train_org\org_ecg_100_510.png
# Resized and saved: resize_train_org\org_ecg_100_520.png
# Resized and saved: resize_train_org\org_ecg_100_530.png
# Resized and saved: resize_train_org\org_ecg_100_540.png
# Resized and saved: resize_train_org\org_ecg_100_550.png
# Resized and saved: resize_train_org\org_ecg_100_560.png
# Resized and saved: resize_train_org\org_ecg_100_570.png
# Resized and saved: resize_train_org\org_ecg_100_580.png
# Resized and saved: resize_train_org\org_ecg_100_590.png
# Resized and saved: resize_train_org\org_ecg_100_60.png
# Resized and saved: resize_train_org\org_ecg_100_600.png
# Resized and saved: resize_train_org\org_ecg_100_610.png
# Resized and saved: resize_train_org\org_ecg_100_620.png
# Resized and saved: resize_train_org\org_ecg_100_630.png
# Resized and saved: resize_train_org\org_ecg_100_640.png
# Resized and saved: resize_train_org\org_ecg_100_650.png
# Resized and saved: resize_train_org\org_ecg_100_660.png
# Resized and saved: resize_train_org\org_ecg_100_670.png
# Resized and saved: resize_train_org\org_ecg_100_680.png
# Resized and saved: resize_train_org\org_ecg_100_690.png
# Resized and saved: resize_train_org\org_ecg_100_70.png
# Resized and saved: resize_train_org\org_ecg_100_700.png
# Resized and saved: resize_train_org\org_ecg_100_710.png
# Resized and saved: resize_train_org\org_ecg_100_720.png
# Resized and saved: resize_train_org\org_ecg_100_730.png
# Resized and saved: resize_train_org\org_ecg_100_740.png
# Resized and saved: resize_train_org\org_ecg_100_750.png
# Resized and saved: resize_train_org\org_ecg_100_760.png
# Resized and saved: resize_train_org\org_ecg_100_770.png
# Resized and saved: resize_train_org\org_ecg_100_780.png
# Resized and saved: resize_train_org\org_ecg_100_790.png
# Resized and saved: resize_train_org\org_ecg_100_80.png
# Resized and saved: resize_train_org\org_ecg_100_800.png
# Resized and saved: resize_train_org\org_ecg_100_810.png
# Resized and saved: resize_train_org\org_ecg_100_820.png
# Resized and saved: resize_train_org\org_ecg_100_830.png
# Resized and saved: resize_train_org\org_ecg_100_840.png
# Resized and saved: resize_train_org\org_ecg_100_850.png
# Resized and saved: resize_train_org\org_ecg_100_860.png
# Resized and saved: resize_train_org\org_ecg_100_870.png
# Resized and saved: resize_train_org\org_ecg_100_880.png
# Resized and saved: resize_train_org\org_ecg_100_890.png
# Resized and saved: resize_train_org\org_ecg_100_90.png
# Resized and saved: resize_train_org\org_ecg_100_900.png
# Resized and saved: resize_train_org\org_ecg_100_910.png
# Resized and saved: resize_train_org\org_ecg_100_920.png
# Resized and saved: resize_train_org\org_ecg_100_930.png
# Resized and saved: resize_train_org\org_ecg_100_940.png
# Resized and saved: resize_train_org\org_ecg_100_950.png
# Resized and saved: resize_train_org\org_ecg_100_960.png
# Resized and saved: resize_train_org\org_ecg_100_970.png
# Resized and saved: resize_train_org\org_ecg_100_980.png
# Resized and saved: resize_train_org\org_ecg_100_990.png
# Resized and saved: resize_train_org\org_ecg_101_100.png
# Resized and saved: resize_train_org\org_ecg_101_1000.png
# Resized and saved: resize_train_org\org_ecg_101_1010.png
# Resized and saved: resize_train_org\org_ecg_101_1020.png
# Resized and saved: resize_train_org\org_ecg_101_1030.png
# Resized and saved: resize_train_org\org_ecg_101_1040.png
# Resized and saved: resize_train_org\org_ecg_101_1050.png
# Resized and saved: resize_train_org\org_ecg_101_1060.png
# Resized and saved: resize_train_org\org_ecg_101_1070.png
# Resized and saved: resize_train_org\org_ecg_101_1080.png
# Resized and saved: resize_train_org\org_ecg_101_1090.png
# Resized and saved: resize_train_org\org_ecg_101_110.png
# Resized and saved: resize_train_org\org_ecg_101_1100.png
# Resized and saved: resize_train_org\org_ecg_101_1110.png
# Resized and saved: resize_train_org\org_ecg_101_1120.png
# Resized and saved: resize_train_org\org_ecg_101_1130.png
# Resized and saved: resize_train_org\org_ecg_101_1140.png
# Resized and saved: resize_train_org\org_ecg_101_1150.png
# Resized and saved: resize_train_org\org_ecg_101_1160.png
# Resized and saved: resize_train_org\org_ecg_101_1170.png
# Resized and saved: resize_train_org\org_ecg_101_1180.png
# Resized and saved: resize_train_org\org_ecg_101_1190.png
# Resized and saved: resize_train_org\org_ecg_101_120.png
# Resized and saved: resize_train_org\org_ecg_101_1200.png
# Resized and saved: resize_train_org\org_ecg_101_1210.png
# Resized and saved: resize_train_org\org_ecg_101_1220.png
# Resized and saved: resize_train_org\org_ecg_101_1230.png
# Resized and saved: resize_train_org\org_ecg_101_1240.png
# Resized and saved: resize_train_org\org_ecg_101_1250.png
# Resized and saved: resize_train_org\org_ecg_101_1260.png
# Resized and saved: resize_train_org\org_ecg_101_1270.png
# Resized and saved: resize_train_org\org_ecg_101_1280.png
# Resized and saved: resize_train_org\org_ecg_101_1290.png
# Resized and saved: resize_train_org\org_ecg_101_130.png
# Resized and saved: resize_train_org\org_ecg_101_1300.png
# Resized and saved: resize_train_org\org_ecg_101_1310.png
# Resized and saved: resize_train_org\org_ecg_101_1320.png
# Resized and saved: resize_train_org\org_ecg_101_1330.png
# Resized and saved: resize_train_org\org_ecg_101_1340.png
# Resized and saved: resize_train_org\org_ecg_101_1350.png
# Resized and saved: resize_train_org\org_ecg_101_1360.png
# Resized and saved: resize_train_org\org_ecg_101_1370.png
# Resized and saved: resize_train_org\org_ecg_101_1380.png
# Resized and saved: resize_train_org\org_ecg_101_1390.png
# Resized and saved: resize_train_org\org_ecg_101_140.png
# Resized and saved: resize_train_org\org_ecg_101_1400.png
# Resized and saved: resize_train_org\org_ecg_101_1410.png
# Resized and saved: resize_train_org\org_ecg_101_1420.png
# Resized and saved: resize_train_org\org_ecg_101_1430.png
# Resized and saved: resize_train_org\org_ecg_101_1440.png
# Resized and saved: resize_train_org\org_ecg_101_1450.png
# Resized and saved: resize_train_org\org_ecg_101_1460.png
# Resized and saved: resize_train_org\org_ecg_101_1470.png
# Resized and saved: resize_train_org\org_ecg_101_1480.png
# Resized and saved: resize_train_org\org_ecg_101_1490.png
# Resized and saved: resize_train_org\org_ecg_101_150.png
# Resized and saved: resize_train_org\org_ecg_101_1500.png
# Resized and saved: resize_train_org\org_ecg_101_1510.png
# Resized and saved: resize_train_org\org_ecg_101_1520.png
# Resized and saved: resize_train_org\org_ecg_101_1530.png
# Resized and saved: resize_train_org\org_ecg_101_1540.png
# Resized and saved: resize_train_org\org_ecg_101_1550.png
# Resized and saved: resize_train_org\org_ecg_101_1560.png
# Resized and saved: resize_train_org\org_ecg_101_1570.png
# Resized and saved: resize_train_org\org_ecg_101_1580.png
# Resized and saved: resize_train_org\org_ecg_101_1590.png
# Resized and saved: resize_train_org\org_ecg_101_160.png
# Resized and saved: resize_train_org\org_ecg_101_1600.png
# Resized and saved: resize_train_org\org_ecg_101_1610.png
# Resized and saved: resize_train_org\org_ecg_101_1620.png
# Resized and saved: resize_train_org\org_ecg_101_1630.png
# Resized and saved: resize_train_org\org_ecg_101_1640.png
# Resized and saved: resize_train_org\org_ecg_101_1650.png
# Resized and saved: resize_train_org\org_ecg_101_1660.png
# Resized and saved: resize_train_org\org_ecg_101_1670.png
# Resized and saved: resize_train_org\org_ecg_101_1680.png
# Resized and saved: resize_train_org\org_ecg_101_1690.png
# Resized and saved: resize_train_org\org_ecg_101_170.png
# Resized and saved: resize_train_org\org_ecg_101_1700.png
# Resized and saved: resize_train_org\org_ecg_101_1710.png
# Resized and saved: resize_train_org\org_ecg_101_1720.png
# Resized and saved: resize_train_org\org_ecg_101_1730.png
# Resized and saved: resize_train_org\org_ecg_101_1740.png
# Resized and saved: resize_train_org\org_ecg_101_1750.png
# Resized and saved: resize_train_org\org_ecg_101_1760.png
# Resized and saved: resize_train_org\org_ecg_101_1770.png
# Resized and saved: resize_train_org\org_ecg_101_1780.png
# Resized and saved: resize_train_org\org_ecg_101_1790.png
# Resized and saved: resize_train_org\org_ecg_101_180.png
# Resized and saved: resize_train_org\org_ecg_101_1800.png
# Resized and saved: resize_train_org\org_ecg_101_190.png
# Resized and saved: resize_train_org\org_ecg_101_20.png
# Resized and saved: resize_train_org\org_ecg_101_200.png
# Resized and saved: resize_train_org\org_ecg_101_210.png
# Resized and saved: resize_train_org\org_ecg_101_220.png
# Resized and saved: resize_train_org\org_ecg_101_230.png
# Resized and saved: resize_train_org\org_ecg_101_240.png
# Resized and saved: resize_train_org\org_ecg_101_250.png
# Resized and saved: resize_train_org\org_ecg_101_260.png
# Resized and saved: resize_train_org\org_ecg_101_270.png
# Resized and saved: resize_train_org\org_ecg_101_280.png
# Resized and saved: resize_train_org\org_ecg_101_290.png
# Resized and saved: resize_train_org\org_ecg_101_30.png
# Resized and saved: resize_train_org\org_ecg_101_300.png
# Resized and saved: resize_train_org\org_ecg_101_310.png
# Resized and saved: resize_train_org\org_ecg_101_320.png
# Resized and saved: resize_train_org\org_ecg_101_330.png
# Resized and saved: resize_train_org\org_ecg_101_340.png
# Resized and saved: resize_train_org\org_ecg_101_350.png
# Resized and saved: resize_train_org\org_ecg_101_360.png
# Resized and saved: resize_train_org\org_ecg_101_370.png
# Resized and saved: resize_train_org\org_ecg_101_380.png
# Resized and saved: resize_train_org\org_ecg_101_390.png
# Resized and saved: resize_train_org\org_ecg_101_40.png
# Resized and saved: resize_train_org\org_ecg_101_400.png
# Resized and saved: resize_train_org\org_ecg_101_410.png
# Resized and saved: resize_train_org\org_ecg_101_420.png
# Resized and saved: resize_train_org\org_ecg_101_430.png
# Resized and saved: resize_train_org\org_ecg_101_440.png
# Resized and saved: resize_train_org\org_ecg_101_450.png
# Resized and saved: resize_train_org\org_ecg_101_460.png
# Resized and saved: resize_train_org\org_ecg_101_470.png
# Resized and saved: resize_train_org\org_ecg_101_480.png
# Resized and saved: resize_train_org\org_ecg_101_490.png
# Resized and saved: resize_train_org\org_ecg_101_50.png
# Resized and saved: resize_train_org\org_ecg_101_500.png
# Resized and saved: resize_train_org\org_ecg_101_510.png
# Resized and saved: resize_train_org\org_ecg_101_520.png
# Resized and saved: resize_train_org\org_ecg_101_530.png
# Resized and saved: resize_train_org\org_ecg_101_540.png
# Resized and saved: resize_train_org\org_ecg_101_550.png
# Resized and saved: resize_train_org\org_ecg_101_560.png
# Resized and saved: resize_train_org\org_ecg_101_570.png
# Resized and saved: resize_train_org\org_ecg_101_580.png
# Resized and saved: resize_train_org\org_ecg_101_590.png
# Resized and saved: resize_train_org\org_ecg_101_60.png
# Resized and saved: resize_train_org\org_ecg_101_600.png
# Resized and saved: resize_train_org\org_ecg_101_610.png
# Resized and saved: resize_train_org\org_ecg_101_620.png
# Resized and saved: resize_train_org\org_ecg_101_630.png
# Resized and saved: resize_train_org\org_ecg_101_640.png
# Resized and saved: resize_train_org\org_ecg_101_650.png
# Resized and saved: resize_train_org\org_ecg_101_660.png
# Resized and saved: resize_train_org\org_ecg_101_670.png
# Resized and saved: resize_train_org\org_ecg_101_680.png
# Resized and saved: resize_train_org\org_ecg_101_690.png
# Resized and saved: resize_train_org\org_ecg_101_70.png
# Resized and saved: resize_train_org\org_ecg_101_700.png
# Resized and saved: resize_train_org\org_ecg_101_710.png
# Resized and saved: resize_train_org\org_ecg_101_720.png
# Resized and saved: resize_train_org\org_ecg_101_730.png
# Resized and saved: resize_train_org\org_ecg_101_740.png
# Resized and saved: resize_train_org\org_ecg_101_750.png
# Resized and saved: resize_train_org\org_ecg_101_760.png
# Resized and saved: resize_train_org\org_ecg_101_770.png
# Resized and saved: resize_train_org\org_ecg_101_780.png
# Resized and saved: resize_train_org\org_ecg_101_790.png
# Resized and saved: resize_train_org\org_ecg_101_80.png
# Resized and saved: resize_train_org\org_ecg_101_800.png
# Resized and saved: resize_train_org\org_ecg_101_810.png
# Resized and saved: resize_train_org\org_ecg_101_820.png
# Resized and saved: resize_train_org\org_ecg_101_830.png
# Resized and saved: resize_train_org\org_ecg_101_840.png
# Resized and saved: resize_train_org\org_ecg_101_850.png
# Resized and saved: resize_train_org\org_ecg_101_860.png
# Resized and saved: resize_train_org\org_ecg_101_870.png
# Resized and saved: resize_train_org\org_ecg_101_880.png
# Resized and saved: resize_train_org\org_ecg_101_890.png
# Resized and saved: resize_train_org\org_ecg_101_90.png
# Resized and saved: resize_train_org\org_ecg_101_900.png
# Resized and saved: resize_train_org\org_ecg_101_910.png
# Resized and saved: resize_train_org\org_ecg_101_920.png
# Resized and saved: resize_train_org\org_ecg_101_930.png
# Resized and saved: resize_train_org\org_ecg_101_940.png
# Resized and saved: resize_train_org\org_ecg_101_950.png
# Resized and saved: resize_train_org\org_ecg_101_960.png
# Resized and saved: resize_train_org\org_ecg_101_970.png
# Resized and saved: resize_train_org\org_ecg_101_980.png
# Resized and saved: resize_train_org\org_ecg_101_990.png
# Resized and saved: resize_train_org\org_ecg_102_100.png
# Resized and saved: resize_train_org\org_ecg_102_1000.png
# Resized and saved: resize_train_org\org_ecg_102_1010.png
# Resized and saved: resize_train_org\org_ecg_102_1020.png
# Resized and saved: resize_train_org\org_ecg_102_1030.png
# Resized and saved: resize_train_org\org_ecg_102_1040.png
# Resized and saved: resize_train_org\org_ecg_102_1050.png
# Resized and saved: resize_train_org\org_ecg_102_1060.png
# Resized and saved: resize_train_org\org_ecg_102_1070.png
# Resized and saved: resize_train_org\org_ecg_102_1080.png
# Resized and saved: resize_train_org\org_ecg_102_1090.png
# Resized and saved: resize_train_org\org_ecg_102_110.png
# Resized and saved: resize_train_org\org_ecg_102_1100.png
# Resized and saved: resize_train_org\org_ecg_102_1110.png
# Resized and saved: resize_train_org\org_ecg_102_1120.png
# Resized and saved: resize_train_org\org_ecg_102_1130.png
# Resized and saved: resize_train_org\org_ecg_102_1140.png
# Resized and saved: resize_train_org\org_ecg_102_1150.png
# Resized and saved: resize_train_org\org_ecg_102_1160.png
# Resized and saved: resize_train_org\org_ecg_102_1170.png
# Resized and saved: resize_train_org\org_ecg_102_1180.png
# Resized and saved: resize_train_org\org_ecg_102_1190.png
# Resized and saved: resize_train_org\org_ecg_102_120.png
# Resized and saved: resize_train_org\org_ecg_102_1200.png
# Resized and saved: resize_train_org\org_ecg_102_1210.png
# Resized and saved: resize_train_org\org_ecg_102_1220.png
# Resized and saved: resize_train_org\org_ecg_102_1230.png
# Resized and saved: resize_train_org\org_ecg_102_1240.png
# Resized and saved: resize_train_org\org_ecg_102_1250.png
# Resized and saved: resize_train_org\org_ecg_102_1260.png
# Resized and saved: resize_train_org\org_ecg_102_1270.png
# Resized and saved: resize_train_org\org_ecg_102_1280.png
# Resized and saved: resize_train_org\org_ecg_102_1290.png
# Resized and saved: resize_train_org\org_ecg_102_130.png
# Resized and saved: resize_train_org\org_ecg_102_1300.png
# Resized and saved: resize_train_org\org_ecg_102_1310.png
# Resized and saved: resize_train_org\org_ecg_102_1320.png
# Resized and saved: resize_train_org\org_ecg_102_1330.png
# Resized and saved: resize_train_org\org_ecg_102_1340.png
# Resized and saved: resize_train_org\org_ecg_102_1350.png
# Resized and saved: resize_train_org\org_ecg_102_1360.png
# Resized and saved: resize_train_org\org_ecg_102_1370.png
# Resized and saved: resize_train_org\org_ecg_102_1380.png
# Resized and saved: resize_train_org\org_ecg_102_1390.png
# Resized and saved: resize_train_org\org_ecg_102_140.png
# Resized and saved: resize_train_org\org_ecg_102_1400.png
# Resized and saved: resize_train_org\org_ecg_102_1410.png
# Resized and saved: resize_train_org\org_ecg_102_1420.png
# Resized and saved: resize_train_org\org_ecg_102_1430.png
# Resized and saved: resize_train_org\org_ecg_102_1440.png
# Resized and saved: resize_train_org\org_ecg_102_1450.png
# Resized and saved: resize_train_org\org_ecg_102_1460.png
# Resized and saved: resize_train_org\org_ecg_102_1470.png
# Resized and saved: resize_train_org\org_ecg_102_1480.png
# Resized and saved: resize_train_org\org_ecg_102_1490.png
# Resized and saved: resize_train_org\org_ecg_102_150.png
# Resized and saved: resize_train_org\org_ecg_102_1500.png
# Resized and saved: resize_train_org\org_ecg_102_1510.png
# Resized and saved: resize_train_org\org_ecg_102_1520.png
# Resized and saved: resize_train_org\org_ecg_102_1530.png
# Resized and saved: resize_train_org\org_ecg_102_1540.png
# Resized and saved: resize_train_org\org_ecg_102_1550.png
# Resized and saved: resize_train_org\org_ecg_102_1560.png
# Resized and saved: resize_train_org\org_ecg_102_1570.png
# Resized and saved: resize_train_org\org_ecg_102_1580.png
# Resized and saved: resize_train_org\org_ecg_102_1590.png
# Resized and saved: resize_train_org\org_ecg_102_160.png
# Resized and saved: resize_train_org\org_ecg_102_1600.png
# Resized and saved: resize_train_org\org_ecg_102_1610.png
# Resized and saved: resize_train_org\org_ecg_102_1620.png
# Resized and saved: resize_train_org\org_ecg_102_1630.png
# Resized and saved: resize_train_org\org_ecg_102_1640.png
# Resized and saved: resize_train_org\org_ecg_102_1650.png
# Resized and saved: resize_train_org\org_ecg_102_1660.png
# Resized and saved: resize_train_org\org_ecg_102_1670.png
# Resized and saved: resize_train_org\org_ecg_102_1680.png
# Resized and saved: resize_train_org\org_ecg_102_1690.png
# Resized and saved: resize_train_org\org_ecg_102_170.png
# Resized and saved: resize_train_org\org_ecg_102_1700.png
# Resized and saved: resize_train_org\org_ecg_102_1710.png
# Resized and saved: resize_train_org\org_ecg_102_1720.png
# Resized and saved: resize_train_org\org_ecg_102_1730.png
# Resized and saved: resize_train_org\org_ecg_102_1740.png
# Resized and saved: resize_train_org\org_ecg_102_1750.png
# Resized and saved: resize_train_org\org_ecg_102_1760.png
# Resized and saved: resize_train_org\org_ecg_102_1770.png
# Resized and saved: resize_train_org\org_ecg_102_1780.png
# Resized and saved: resize_train_org\org_ecg_102_1790.png
# Resized and saved: resize_train_org\org_ecg_102_180.png
# Resized and saved: resize_train_org\org_ecg_102_1800.png
# Resized and saved: resize_train_org\org_ecg_102_190.png
# Resized and saved: resize_train_org\org_ecg_102_20.png
# Resized and saved: resize_train_org\org_ecg_102_200.png
# Resized and saved: resize_train_org\org_ecg_102_210.png
# Resized and saved: resize_train_org\org_ecg_102_220.png
# Resized and saved: resize_train_org\org_ecg_102_230.png
# Resized and saved: resize_train_org\org_ecg_102_240.png
# Resized and saved: resize_train_org\org_ecg_102_250.png
# Resized and saved: resize_train_org\org_ecg_102_260.png
# Resized and saved: resize_train_org\org_ecg_102_270.png
# Resized and saved: resize_train_org\org_ecg_102_280.png
# Resized and saved: resize_train_org\org_ecg_102_290.png
# Resized and saved: resize_train_org\org_ecg_102_30.png
# Resized and saved: resize_train_org\org_ecg_102_300.png
# Resized and saved: resize_train_org\org_ecg_102_310.png
# Resized and saved: resize_train_org\org_ecg_102_320.png
# Resized and saved: resize_train_org\org_ecg_102_330.png
# Resized and saved: resize_train_org\org_ecg_102_340.png
# Resized and saved: resize_train_org\org_ecg_102_350.png
# Resized and saved: resize_train_org\org_ecg_102_360.png
# Resized and saved: resize_train_org\org_ecg_102_370.png
# Resized and saved: resize_train_org\org_ecg_102_380.png
# Resized and saved: resize_train_org\org_ecg_102_390.png
# Resized and saved: resize_train_org\org_ecg_102_40.png
# Resized and saved: resize_train_org\org_ecg_102_400.png
# Resized and saved: resize_train_org\org_ecg_102_410.png
# Resized and saved: resize_train_org\org_ecg_102_420.png
# Resized and saved: resize_train_org\org_ecg_102_430.png
# Resized and saved: resize_train_org\org_ecg_102_440.png
# Resized and saved: resize_train_org\org_ecg_102_450.png
# Resized and saved: resize_train_org\org_ecg_102_460.png
# Resized and saved: resize_train_org\org_ecg_102_470.png
# Resized and saved: resize_train_org\org_ecg_102_480.png
# Resized and saved: resize_train_org\org_ecg_102_490.png
# Resized and saved: resize_train_org\org_ecg_102_50.png
# Resized and saved: resize_train_org\org_ecg_102_500.png
# Resized and saved: resize_train_org\org_ecg_102_510.png
# Resized and saved: resize_train_org\org_ecg_102_520.png
# Resized and saved: resize_train_org\org_ecg_102_530.png
# Resized and saved: resize_train_org\org_ecg_102_540.png
# Resized and saved: resize_train_org\org_ecg_102_550.png
# Resized and saved: resize_train_org\org_ecg_102_560.png
# Resized and saved: resize_train_org\org_ecg_102_570.png
# Resized and saved: resize_train_org\org_ecg_102_580.png
# Resized and saved: resize_train_org\org_ecg_102_590.png
# Resized and saved: resize_train_org\org_ecg_102_60.png
# Resized and saved: resize_train_org\org_ecg_102_600.png
# Resized and saved: resize_train_org\org_ecg_102_610.png
# Resized and saved: resize_train_org\org_ecg_102_620.png
# Resized and saved: resize_train_org\org_ecg_102_630.png
# Resized and saved: resize_train_org\org_ecg_102_640.png
# Resized and saved: resize_train_org\org_ecg_102_650.png
# Resized and saved: resize_train_org\org_ecg_102_660.png
# Resized and saved: resize_train_org\org_ecg_102_670.png
# Resized and saved: resize_train_org\org_ecg_102_680.png
# Resized and saved: resize_train_org\org_ecg_102_690.png
# Resized and saved: resize_train_org\org_ecg_102_70.png
# Resized and saved: resize_train_org\org_ecg_102_700.png
# Resized and saved: resize_train_org\org_ecg_102_710.png
# Resized and saved: resize_train_org\org_ecg_102_720.png
# Resized and saved: resize_train_org\org_ecg_102_730.png
# Resized and saved: resize_train_org\org_ecg_102_740.png
# Resized and saved: resize_train_org\org_ecg_102_750.png
# Resized and saved: resize_train_org\org_ecg_102_760.png
# Resized and saved: resize_train_org\org_ecg_102_770.png
# Resized and saved: resize_train_org\org_ecg_102_780.png
# Resized and saved: resize_train_org\org_ecg_102_790.png
# Resized and saved: resize_train_org\org_ecg_102_80.png
# Resized and saved: resize_train_org\org_ecg_102_800.png
# Resized and saved: resize_train_org\org_ecg_102_810.png
# Resized and saved: resize_train_org\org_ecg_102_820.png
# Resized and saved: resize_train_org\org_ecg_102_830.png
# Resized and saved: resize_train_org\org_ecg_102_840.png
# Resized and saved: resize_train_org\org_ecg_102_850.png
# Resized and saved: resize_train_org\org_ecg_102_860.png
# Resized and saved: resize_train_org\org_ecg_102_870.png
# Resized and saved: resize_train_org\org_ecg_102_880.png
# Resized and saved: resize_train_org\org_ecg_102_890.png
# Resized and saved: resize_train_org\org_ecg_102_90.png
# Resized and saved: resize_train_org\org_ecg_102_900.png
# Resized and saved: resize_train_org\org_ecg_102_910.png
# Resized and saved: resize_train_org\org_ecg_102_920.png
# Resized and saved: resize_train_org\org_ecg_102_930.png
# Resized and saved: resize_train_org\org_ecg_102_940.png
# Resized and saved: resize_train_org\org_ecg_102_950.png
# Resized and saved: resize_train_org\org_ecg_102_960.png
# Resized and saved: resize_train_org\org_ecg_102_970.png
# Resized and saved: resize_train_org\org_ecg_102_980.png
# Resized and saved: resize_train_org\org_ecg_102_990.png
# Resized and saved: resize_train_org\org_ecg_103_100.png
# Resized and saved: resize_train_org\org_ecg_103_1000.png
# Resized and saved: resize_train_org\org_ecg_103_1010.png
# Resized and saved: resize_train_org\org_ecg_103_1020.png
# Resized and saved: resize_train_org\org_ecg_103_1030.png
# Resized and saved: resize_train_org\org_ecg_103_1040.png
# Resized and saved: resize_train_org\org_ecg_103_1050.png
# Resized and saved: resize_train_org\org_ecg_103_1060.png
# Resized and saved: resize_train_org\org_ecg_103_1070.png
# Resized and saved: resize_train_org\org_ecg_103_1080.png
# Resized and saved: resize_train_org\org_ecg_103_1090.png
# Resized and saved: resize_train_org\org_ecg_103_110.png
# Resized and saved: resize_train_org\org_ecg_103_1100.png
# Resized and saved: resize_train_org\org_ecg_103_1110.png
# Resized and saved: resize_train_org\org_ecg_103_1120.png
# Resized and saved: resize_train_org\org_ecg_103_1130.png
# Resized and saved: resize_train_org\org_ecg_103_1140.png
# Resized and saved: resize_train_org\org_ecg_103_1150.png
# Resized and saved: resize_train_org\org_ecg_103_1160.png
# Resized and saved: resize_train_org\org_ecg_103_1170.png
# Resized and saved: resize_train_org\org_ecg_103_1180.png
# Resized and saved: resize_train_org\org_ecg_103_1190.png
# Resized and saved: resize_train_org\org_ecg_103_120.png
# Resized and saved: resize_train_org\org_ecg_103_1200.png
# Resized and saved: resize_train_org\org_ecg_103_1210.png
# Resized and saved: resize_train_org\org_ecg_103_1220.png
# Resized and saved: resize_train_org\org_ecg_103_1230.png
# Resized and saved: resize_train_org\org_ecg_103_1240.png
# Resized and saved: resize_train_org\org_ecg_103_1250.png
# Resized and saved: resize_train_org\org_ecg_103_1260.png
# Resized and saved: resize_train_org\org_ecg_103_1270.png
# Resized and saved: resize_train_org\org_ecg_103_1280.png
# Resized and saved: resize_train_org\org_ecg_103_1290.png
# Resized and saved: resize_train_org\org_ecg_103_130.png
# Resized and saved: resize_train_org\org_ecg_103_1300.png
# Resized and saved: resize_train_org\org_ecg_103_1310.png
# Resized and saved: resize_train_org\org_ecg_103_1320.png
# Resized and saved: resize_train_org\org_ecg_103_1330.png
# Resized and saved: resize_train_org\org_ecg_103_1340.png
# Resized and saved: resize_train_org\org_ecg_103_1350.png
# Resized and saved: resize_train_org\org_ecg_103_1360.png
# Resized and saved: resize_train_org\org_ecg_103_1370.png
# Resized and saved: resize_train_org\org_ecg_103_1380.png
# Resized and saved: resize_train_org\org_ecg_103_1390.png
# Resized and saved: resize_train_org\org_ecg_103_140.png
# Resized and saved: resize_train_org\org_ecg_103_1400.png
# Resized and saved: resize_train_org\org_ecg_103_1410.png
# Resized and saved: resize_train_org\org_ecg_103_1420.png
# Resized and saved: resize_train_org\org_ecg_103_1430.png
# Resized and saved: resize_train_org\org_ecg_103_1440.png
# Resized and saved: resize_train_org\org_ecg_103_1450.png
# Resized and saved: resize_train_org\org_ecg_103_1460.png
# Resized and saved: resize_train_org\org_ecg_103_1470.png
# Resized and saved: resize_train_org\org_ecg_103_1480.png
# Resized and saved: resize_train_org\org_ecg_103_1490.png
# Resized and saved: resize_train_org\org_ecg_103_150.png
# Resized and saved: resize_train_org\org_ecg_103_1500.png
# Resized and saved: resize_train_org\org_ecg_103_1510.png
# Resized and saved: resize_train_org\org_ecg_103_1520.png
# Resized and saved: resize_train_org\org_ecg_103_1530.png
# Resized and saved: resize_train_org\org_ecg_103_1540.png
# Resized and saved: resize_train_org\org_ecg_103_1550.png
# Resized and saved: resize_train_org\org_ecg_103_1560.png
# Resized and saved: resize_train_org\org_ecg_103_1570.png
# Resized and saved: resize_train_org\org_ecg_103_1580.png
# Resized and saved: resize_train_org\org_ecg_103_1590.png
# Resized and saved: resize_train_org\org_ecg_103_160.png
# Resized and saved: resize_train_org\org_ecg_103_1600.png
# Resized and saved: resize_train_org\org_ecg_103_1610.png
# Resized and saved: resize_train_org\org_ecg_103_1620.png
# Resized and saved: resize_train_org\org_ecg_103_1630.png
# Resized and saved: resize_train_org\org_ecg_103_1640.png
# Resized and saved: resize_train_org\org_ecg_103_1650.png
# Resized and saved: resize_train_org\org_ecg_103_1660.png
# Resized and saved: resize_train_org\org_ecg_103_1670.png
# Resized and saved: resize_train_org\org_ecg_103_1680.png
# Resized and saved: resize_train_org\org_ecg_103_1690.png
# Resized and saved: resize_train_org\org_ecg_103_170.png
# Resized and saved: resize_train_org\org_ecg_103_1700.png
# Resized and saved: resize_train_org\org_ecg_103_1710.png
# Resized and saved: resize_train_org\org_ecg_103_1720.png
# Resized and saved: resize_train_org\org_ecg_103_1730.png
# Resized and saved: resize_train_org\org_ecg_103_1740.png
# Resized and saved: resize_train_org\org_ecg_103_1750.png
# Resized and saved: resize_train_org\org_ecg_103_1760.png
# Resized and saved: resize_train_org\org_ecg_103_1770.png
# Resized and saved: resize_train_org\org_ecg_103_1780.png
# Resized and saved: resize_train_org\org_ecg_103_1790.png
# Resized and saved: resize_train_org\org_ecg_103_180.png
# Resized and saved: resize_train_org\org_ecg_103_1800.png
# Resized and saved: resize_train_org\org_ecg_103_190.png
# Resized and saved: resize_train_org\org_ecg_103_20.png
# Resized and saved: resize_train_org\org_ecg_103_200.png
# Resized and saved: resize_train_org\org_ecg_103_210.png
# Resized and saved: resize_train_org\org_ecg_103_220.png
# Resized and saved: resize_train_org\org_ecg_103_230.png
# Resized and saved: resize_train_org\org_ecg_103_240.png
# Resized and saved: resize_train_org\org_ecg_103_250.png
# Resized and saved: resize_train_org\org_ecg_103_260.png
# Resized and saved: resize_train_org\org_ecg_103_270.png
# Resized and saved: resize_train_org\org_ecg_103_280.png
# Resized and saved: resize_train_org\org_ecg_103_290.png
# Resized and saved: resize_train_org\org_ecg_103_30.png
# Resized and saved: resize_train_org\org_ecg_103_300.png
# Resized and saved: resize_train_org\org_ecg_103_310.png
# Resized and saved: resize_train_org\org_ecg_103_320.png
# Resized and saved: resize_train_org\org_ecg_103_330.png
# Resized and saved: resize_train_org\org_ecg_103_340.png
# Resized and saved: resize_train_org\org_ecg_103_350.png
# Resized and saved: resize_train_org\org_ecg_103_360.png
# Resized and saved: resize_train_org\org_ecg_103_370.png
# Resized and saved: resize_train_org\org_ecg_103_380.png
# Resized and saved: resize_train_org\org_ecg_103_390.png
# Resized and saved: resize_train_org\org_ecg_103_40.png
# Resized and saved: resize_train_org\org_ecg_103_400.png
# Resized and saved: resize_train_org\org_ecg_103_410.png
# Resized and saved: resize_train_org\org_ecg_103_420.png
# Resized and saved: resize_train_org\org_ecg_103_430.png
# Resized and saved: resize_train_org\org_ecg_103_440.png
# Resized and saved: resize_train_org\org_ecg_103_450.png
# Resized and saved: resize_train_org\org_ecg_103_460.png
# Resized and saved: resize_train_org\org_ecg_103_470.png
# Resized and saved: resize_train_org\org_ecg_103_480.png
# Resized and saved: resize_train_org\org_ecg_103_490.png
# Resized and saved: resize_train_org\org_ecg_103_50.png
# Resized and saved: resize_train_org\org_ecg_103_500.png
# Resized and saved: resize_train_org\org_ecg_103_510.png
# Resized and saved: resize_train_org\org_ecg_103_520.png
# Resized and saved: resize_train_org\org_ecg_103_530.png
# Resized and saved: resize_train_org\org_ecg_103_540.png
# Resized and saved: resize_train_org\org_ecg_103_550.png
# Resized and saved: resize_train_org\org_ecg_103_560.png
# Resized and saved: resize_train_org\org_ecg_103_570.png
# Resized and saved: resize_train_org\org_ecg_103_580.png
# Resized and saved: resize_train_org\org_ecg_103_590.png
# Resized and saved: resize_train_org\org_ecg_103_60.png
# Resized and saved: resize_train_org\org_ecg_103_600.png
# Resized and saved: resize_train_org\org_ecg_103_610.png
# Resized and saved: resize_train_org\org_ecg_103_620.png
# Resized and saved: resize_train_org\org_ecg_103_630.png
# Resized and saved: resize_train_org\org_ecg_103_640.png
# Resized and saved: resize_train_org\org_ecg_103_650.png
# Resized and saved: resize_train_org\org_ecg_103_660.png
# Resized and saved: resize_train_org\org_ecg_103_670.png
# Resized and saved: resize_train_org\org_ecg_103_680.png
# Resized and saved: resize_train_org\org_ecg_103_690.png
# Resized and saved: resize_train_org\org_ecg_103_70.png
# Resized and saved: resize_train_org\org_ecg_103_700.png
# Resized and saved: resize_train_org\org_ecg_103_710.png
# Resized and saved: resize_train_org\org_ecg_103_720.png
# Resized and saved: resize_train_org\org_ecg_103_730.png
# Resized and saved: resize_train_org\org_ecg_103_740.png
# Resized and saved: resize_train_org\org_ecg_103_750.png
# Resized and saved: resize_train_org\org_ecg_103_760.png
# Resized and saved: resize_train_org\org_ecg_103_770.png
# Resized and saved: resize_train_org\org_ecg_103_780.png
# Resized and saved: resize_train_org\org_ecg_103_790.png
# Resized and saved: resize_train_org\org_ecg_103_80.png
# Resized and saved: resize_train_org\org_ecg_103_800.png
# Resized and saved: resize_train_org\org_ecg_103_810.png
# Resized and saved: resize_train_org\org_ecg_103_820.png
# Resized and saved: resize_train_org\org_ecg_103_830.png
# Resized and saved: resize_train_org\org_ecg_103_840.png
# Resized and saved: resize_train_org\org_ecg_103_850.png
# Resized and saved: resize_train_org\org_ecg_103_860.png
# Resized and saved: resize_train_org\org_ecg_103_870.png
# Resized and saved: resize_train_org\org_ecg_103_880.png
# Resized and saved: resize_train_org\org_ecg_103_890.png
# Resized and saved: resize_train_org\org_ecg_103_90.png
# Resized and saved: resize_train_org\org_ecg_103_900.png
# Resized and saved: resize_train_org\org_ecg_103_910.png
# Resized and saved: resize_train_org\org_ecg_103_920.png
# Resized and saved: resize_train_org\org_ecg_103_930.png
# Resized and saved: resize_train_org\org_ecg_103_940.png
# Resized and saved: resize_train_org\org_ecg_103_950.png
# Resized and saved: resize_train_org\org_ecg_103_960.png
# Resized and saved: resize_train_org\org_ecg_103_970.png
# Resized and saved: resize_train_org\org_ecg_103_980.png
# Resized and saved: resize_train_org\org_ecg_103_990.png
# Resized and saved: resize_train_org\org_ecg_104_100.png
# Resized and saved: resize_train_org\org_ecg_104_1000.png
# Resized and saved: resize_train_org\org_ecg_104_1010.png
# Resized and saved: resize_train_org\org_ecg_104_1020.png
# Resized and saved: resize_train_org\org_ecg_104_1030.png
# Resized and saved: resize_train_org\org_ecg_104_1040.png
# Resized and saved: resize_train_org\org_ecg_104_1050.png
# Resized and saved: resize_train_org\org_ecg_104_1060.png
# Resized and saved: resize_train_org\org_ecg_104_1070.png
# Resized and saved: resize_train_org\org_ecg_104_1080.png
# Resized and saved: resize_train_org\org_ecg_104_1090.png
# Resized and saved: resize_train_org\org_ecg_104_110.png
# Resized and saved: resize_train_org\org_ecg_104_1100.png
# Resized and saved: resize_train_org\org_ecg_104_1110.png
# Resized and saved: resize_train_org\org_ecg_104_1120.png
# Resized and saved: resize_train_org\org_ecg_104_1130.png
# Resized and saved: resize_train_org\org_ecg_104_1140.png
# Resized and saved: resize_train_org\org_ecg_104_1150.png
# Resized and saved: resize_train_org\org_ecg_104_1160.png
# Resized and saved: resize_train_org\org_ecg_104_1170.png
# Resized and saved: resize_train_org\org_ecg_104_1180.png
# Resized and saved: resize_train_org\org_ecg_104_1190.png
# Resized and saved: resize_train_org\org_ecg_104_120.png
# Resized and saved: resize_train_org\org_ecg_104_1200.png
# Resized and saved: resize_train_org\org_ecg_104_1210.png
# Resized and saved: resize_train_org\org_ecg_104_1220.png
# Resized and saved: resize_train_org\org_ecg_104_1230.png
# Resized and saved: resize_train_org\org_ecg_104_1240.png
# Resized and saved: resize_train_org\org_ecg_104_1250.png
# Resized and saved: resize_train_org\org_ecg_104_1260.png
# Resized and saved: resize_train_org\org_ecg_104_1270.png
# Resized and saved: resize_train_org\org_ecg_104_1280.png
# Resized and saved: resize_train_org\org_ecg_104_1290.png
# Resized and saved: resize_train_org\org_ecg_104_130.png
# Resized and saved: resize_train_org\org_ecg_104_1300.png
# Resized and saved: resize_train_org\org_ecg_104_1310.png
# Resized and saved: resize_train_org\org_ecg_104_1320.png
# Resized and saved: resize_train_org\org_ecg_104_1330.png
# Resized and saved: resize_train_org\org_ecg_104_1340.png
# Resized and saved: resize_train_org\org_ecg_104_1350.png
# Resized and saved: resize_train_org\org_ecg_104_1360.png
# Resized and saved: resize_train_org\org_ecg_104_1370.png
# Resized and saved: resize_train_org\org_ecg_104_1380.png
# Resized and saved: resize_train_org\org_ecg_104_1390.png
# Resized and saved: resize_train_org\org_ecg_104_140.png
# Resized and saved: resize_train_org\org_ecg_104_1400.png
# Resized and saved: resize_train_org\org_ecg_104_1410.png
# Resized and saved: resize_train_org\org_ecg_104_1420.png
# Resized and saved: resize_train_org\org_ecg_104_1430.png
# Resized and saved: resize_train_org\org_ecg_104_1440.png
# Resized and saved: resize_train_org\org_ecg_104_1450.png
# Resized and saved: resize_train_org\org_ecg_104_1460.png
# Resized and saved: resize_train_org\org_ecg_104_1470.png
# Resized and saved: resize_train_org\org_ecg_104_1480.png
# Resized and saved: resize_train_org\org_ecg_104_1490.png
# Resized and saved: resize_train_org\org_ecg_104_150.png
# Resized and saved: resize_train_org\org_ecg_104_1500.png
# Resized and saved: resize_train_org\org_ecg_104_1510.png
# Resized and saved: resize_train_org\org_ecg_104_1520.png
# Resized and saved: resize_train_org\org_ecg_104_1530.png
# Resized and saved: resize_train_org\org_ecg_104_1540.png
# Resized and saved: resize_train_org\org_ecg_104_1550.png
# Resized and saved: resize_train_org\org_ecg_104_1560.png
# Resized and saved: resize_train_org\org_ecg_104_1570.png
# Resized and saved: resize_train_org\org_ecg_104_1580.png
# Resized and saved: resize_train_org\org_ecg_104_1590.png
# Resized and saved: resize_train_org\org_ecg_104_160.png
# Resized and saved: resize_train_org\org_ecg_104_1600.png
# Resized and saved: resize_train_org\org_ecg_104_1610.png
# Resized and saved: resize_train_org\org_ecg_104_1620.png
# Resized and saved: resize_train_org\org_ecg_104_1630.png
# Resized and saved: resize_train_org\org_ecg_104_1640.png
# Resized and saved: resize_train_org\org_ecg_104_1650.png
# Resized and saved: resize_train_org\org_ecg_104_1660.png
# Resized and saved: resize_train_org\org_ecg_104_1670.png
# Resized and saved: resize_train_org\org_ecg_104_1680.png
# Resized and saved: resize_train_org\org_ecg_104_1690.png
# Resized and saved: resize_train_org\org_ecg_104_170.png
# Resized and saved: resize_train_org\org_ecg_104_1700.png
# Resized and saved: resize_train_org\org_ecg_104_1710.png
# Resized and saved: resize_train_org\org_ecg_104_1720.png
# Resized and saved: resize_train_org\org_ecg_104_1730.png
# Resized and saved: resize_train_org\org_ecg_104_1740.png
# Resized and saved: resize_train_org\org_ecg_104_1750.png
# Resized and saved: resize_train_org\org_ecg_104_1760.png
# Resized and saved: resize_train_org\org_ecg_104_1770.png
# Resized and saved: resize_train_org\org_ecg_104_1780.png
# Resized and saved: resize_train_org\org_ecg_104_1790.png
# Resized and saved: resize_train_org\org_ecg_104_180.png
# Resized and saved: resize_train_org\org_ecg_104_1800.png
# Resized and saved: resize_train_org\org_ecg_104_190.png
# Resized and saved: resize_train_org\org_ecg_104_20.png
# Resized and saved: resize_train_org\org_ecg_104_200.png
# Resized and saved: resize_train_org\org_ecg_104_210.png
# Resized and saved: resize_train_org\org_ecg_104_220.png
# Resized and saved: resize_train_org\org_ecg_104_230.png
# Resized and saved: resize_train_org\org_ecg_104_240.png
# Resized and saved: resize_train_org\org_ecg_104_250.png
# Resized and saved: resize_train_org\org_ecg_104_260.png
# Resized and saved: resize_train_org\org_ecg_104_270.png
# Resized and saved: resize_train_org\org_ecg_104_280.png
# Resized and saved: resize_train_org\org_ecg_104_290.png
# Resized and saved: resize_train_org\org_ecg_104_30.png
# Resized and saved: resize_train_org\org_ecg_104_300.png
# Resized and saved: resize_train_org\org_ecg_104_310.png
# Resized and saved: resize_train_org\org_ecg_104_320.png
# Resized and saved: resize_train_org\org_ecg_104_330.png
# Resized and saved: resize_train_org\org_ecg_104_340.png
# Resized and saved: resize_train_org\org_ecg_104_350.png
# Resized and saved: resize_train_org\org_ecg_104_360.png
# Resized and saved: resize_train_org\org_ecg_104_370.png
# Resized and saved: resize_train_org\org_ecg_104_380.png
# Resized and saved: resize_train_org\org_ecg_104_390.png
# Resized and saved: resize_train_org\org_ecg_104_40.png
# Resized and saved: resize_train_org\org_ecg_104_400.png
# Resized and saved: resize_train_org\org_ecg_104_410.png
# Resized and saved: resize_train_org\org_ecg_104_420.png
# Resized and saved: resize_train_org\org_ecg_104_430.png
# Resized and saved: resize_train_org\org_ecg_104_440.png
# Resized and saved: resize_train_org\org_ecg_104_450.png
# Resized and saved: resize_train_org\org_ecg_104_460.png
# Resized and saved: resize_train_org\org_ecg_104_470.png
# Resized and saved: resize_train_org\org_ecg_104_480.png
# Resized and saved: resize_train_org\org_ecg_104_490.png
# Resized and saved: resize_train_org\org_ecg_104_50.png
# Resized and saved: resize_train_org\org_ecg_104_500.png
# Resized and saved: resize_train_org\org_ecg_104_510.png
# Resized and saved: resize_train_org\org_ecg_104_520.png
# Resized and saved: resize_train_org\org_ecg_104_530.png
# Resized and saved: resize_train_org\org_ecg_104_540.png
# Resized and saved: resize_train_org\org_ecg_104_550.png
# Resized and saved: resize_train_org\org_ecg_104_560.png
# Resized and saved: resize_train_org\org_ecg_104_570.png
# Resized and saved: resize_train_org\org_ecg_104_580.png
# ...
# Resized and saved: resize_train_org\org_ecg_233_1680.png
# Resized and saved: resize_train_org\org_ecg_233_1690.png
# Resized and saved: resize_train_org\org_ecg_233_170.png
# Resized and saved: resize_train_org\org_ecg_233_1700.png
# Resized and saved: resize_train_org\org_ecg_233_1710.png
# Resized and saved: resize_train_org\org_ecg_233_1720.png
# Resized and saved: resize_train_org\org_ecg_233_1730.png
# Resized and saved: resize_train_org\org_ecg_233_1740.png
# Resized and saved: resize_train_org\org_ecg_233_1750.png
# Resized and saved: resize_train_org\org_ecg_233_1760.png
# Resized and saved: resize_train_org\org_ecg_233_1770.png
# Resized and saved: resize_train_org\org_ecg_233_1780.png
# Resized and saved: resize_train_org\org_ecg_233_1790.png
# Resized and saved: resize_train_org\org_ecg_233_180.png
# Resized and saved: resize_train_org\org_ecg_233_1800.png
# Resized and saved: resize_train_org\org_ecg_233_190.png
# Resized and saved: resize_train_org\org_ecg_233_20.png
# Resized and saved: resize_train_org\org_ecg_233_200.png
# Resized and saved: resize_train_org\org_ecg_233_210.png
# Resized and saved: resize_train_org\org_ecg_233_220.png
# Resized and saved: resize_train_org\org_ecg_233_230.png
# Resized and saved: resize_train_org\org_ecg_233_240.png
# Resized and saved: resize_train_org\org_ecg_233_250.png
# Resized and saved: resize_train_org\org_ecg_233_260.png
# Resized and saved: resize_train_org\org_ecg_233_270.png
# Resized and saved: resize_train_org\org_ecg_233_280.png
# Resized and saved: resize_train_org\org_ecg_233_290.png
# Resized and saved: resize_train_org\org_ecg_233_30.png
# Resized and saved: resize_train_org\org_ecg_233_300.png
# Resized and saved: resize_train_org\org_ecg_233_310.png
# Resized and saved: resize_train_org\org_ecg_233_320.png
# Resized and saved: resize_train_org\org_ecg_233_330.png
# Resized and saved: resize_train_org\org_ecg_233_340.png
# Resized and saved: resize_train_org\org_ecg_233_350.png
# Resized and saved: resize_train_org\org_ecg_233_360.png
# Resized and saved: resize_train_org\org_ecg_233_370.png
# Resized and saved: resize_train_org\org_ecg_233_380.png
# Resized and saved: resize_train_org\org_ecg_233_390.png
# Resized and saved: resize_train_org\org_ecg_233_40.png
# Resized and saved: resize_train_org\org_ecg_233_400.png
# Resized and saved: resize_train_org\org_ecg_233_410.png
# Resized and saved: resize_train_org\org_ecg_233_420.png
# Resized and saved: resize_train_org\org_ecg_233_430.png
# Resized and saved: resize_train_org\org_ecg_233_440.png
# Resized and saved: resize_train_org\org_ecg_233_450.png
# Resized and saved: resize_train_org\org_ecg_233_460.png
# Resized and saved: resize_train_org\org_ecg_233_470.png
# Resized and saved: resize_train_org\org_ecg_233_480.png
# Resized and saved: resize_train_org\org_ecg_233_490.png
# Resized and saved: resize_train_org\org_ecg_233_50.png
# Resized and saved: resize_train_org\org_ecg_233_500.png
# Resized and saved: resize_train_org\org_ecg_233_510.png
# Resized and saved: resize_train_org\org_ecg_233_520.png
# Resized and saved: resize_train_org\org_ecg_233_530.png
# Resized and saved: resize_train_org\org_ecg_233_540.png
# Resized and saved: resize_train_org\org_ecg_233_550.png
# Resized and saved: resize_train_org\org_ecg_233_560.png
# Resized and saved: resize_train_org\org_ecg_233_570.png
# Resized and saved: resize_train_org\org_ecg_233_580.png
# Resized and saved: resize_train_org\org_ecg_233_590.png
# Resized and saved: resize_train_org\org_ecg_233_60.png
# Resized and saved: resize_train_org\org_ecg_233_600.png
# Resized and saved: resize_train_org\org_ecg_233_610.png
# Resized and saved: resize_train_org\org_ecg_233_620.png
# Resized and saved: resize_train_org\org_ecg_233_630.png
# Resized and saved: resize_train_org\org_ecg_233_640.png
# Resized and saved: resize_train_org\org_ecg_233_650.png
# Resized and saved: resize_train_org\org_ecg_233_660.png
# Resized and saved: resize_train_org\org_ecg_233_670.png
# Resized and saved: resize_train_org\org_ecg_233_680.png
# Resized and saved: resize_train_org\org_ecg_233_690.png
# Resized and saved: resize_train_org\org_ecg_233_70.png
# Resized and saved: resize_train_org\org_ecg_233_700.png
# Resized and saved: resize_train_org\org_ecg_233_710.png
# Resized and saved: resize_train_org\org_ecg_233_720.png
# Resized and saved: resize_train_org\org_ecg_233_730.png
# Resized and saved: resize_train_org\org_ecg_233_740.png
# Resized and saved: resize_train_org\org_ecg_233_750.png
# Resized and saved: resize_train_org\org_ecg_233_760.png
# Resized and saved: resize_train_org\org_ecg_233_770.png
# Resized and saved: resize_train_org\org_ecg_233_780.png
# Resized and saved: resize_train_org\org_ecg_233_790.png
# Resized and saved: resize_train_org\org_ecg_233_80.png
# Resized and saved: resize_train_org\org_ecg_233_800.png
# Resized and saved: resize_train_org\org_ecg_233_810.png
# Resized and saved: resize_train_org\org_ecg_233_820.png
# Resized and saved: resize_train_org\org_ecg_233_830.png
# Resized and saved: resize_train_org\org_ecg_233_840.png
# Resized and saved: resize_train_org\org_ecg_233_850.png
# Resized and saved: resize_train_org\org_ecg_233_860.png
# Resized and saved: resize_train_org\org_ecg_233_870.png
# Resized and saved: resize_train_org\org_ecg_233_880.png
# Resized and saved: resize_train_org\org_ecg_233_890.png
# Resized and saved: resize_train_org\org_ecg_233_90.png
# Resized and saved: resize_train_org\org_ecg_233_900.png
# Resized and saved: resize_train_org\org_ecg_233_910.png
# Resized and saved: resize_train_org\org_ecg_233_920.png
# Resized and saved: resize_train_org\org_ecg_233_930.png
# Resized and saved: resize_train_org\org_ecg_233_940.png
# Resized and saved: resize_train_org\org_ecg_233_950.png
# Resized and saved: resize_train_org\org_ecg_233_960.png
# Resized and saved: resize_train_org\org_ecg_233_970.png
# Resized and saved: resize_train_org\org_ecg_233_980.png
# Resized and saved: resize_train_org\org_ecg_233_990.png
# Resized and saved: resize_train_org\org_ecg_234_100.png
# Resized and saved: resize_train_org\org_ecg_234_1000.png
# Resized and saved: resize_train_org\org_ecg_234_1010.png
# Resized and saved: resize_train_org\org_ecg_234_1020.png
# Resized and saved: resize_train_org\org_ecg_234_1030.png
# Resized and saved: resize_train_org\org_ecg_234_1040.png
# Resized and saved: resize_train_org\org_ecg_234_1050.png
# Resized and saved: resize_train_org\org_ecg_234_1060.png
# Resized and saved: resize_train_org\org_ecg_234_1070.png
# Resized and saved: resize_train_org\org_ecg_234_1080.png
# Resized and saved: resize_train_org\org_ecg_234_1090.png
# Resized and saved: resize_train_org\org_ecg_234_110.png
# Resized and saved: resize_train_org\org_ecg_234_1100.png
# Resized and saved: resize_train_org\org_ecg_234_1110.png
# Resized and saved: resize_train_org\org_ecg_234_1120.png
# Resized and saved: resize_train_org\org_ecg_234_1130.png
# Resized and saved: resize_train_org\org_ecg_234_1140.png
# Resized and saved: resize_train_org\org_ecg_234_1150.png
# Resized and saved: resize_train_org\org_ecg_234_1160.png
# Resized and saved: resize_train_org\org_ecg_234_1170.png
# Resized and saved: resize_train_org\org_ecg_234_1180.png
# Resized and saved: resize_train_org\org_ecg_234_1190.png
# Resized and saved: resize_train_org\org_ecg_234_120.png
# Resized and saved: resize_train_org\org_ecg_234_1200.png
# Resized and saved: resize_train_org\org_ecg_234_1210.png
# Resized and saved: resize_train_org\org_ecg_234_1220.png
# Resized and saved: resize_train_org\org_ecg_234_1230.png
# Resized and saved: resize_train_org\org_ecg_234_1240.png
# Resized and saved: resize_train_org\org_ecg_234_1250.png
# Resized and saved: resize_train_org\org_ecg_234_1260.png
# Resized and saved: resize_train_org\org_ecg_234_1270.png
# Resized and saved: resize_train_org\org_ecg_234_1280.png
# Resized and saved: resize_train_org\org_ecg_234_1290.png
# Resized and saved: resize_train_org\org_ecg_234_130.png
# Resized and saved: resize_train_org\org_ecg_234_1300.png
# Resized and saved: resize_train_org\org_ecg_234_1310.png
# Resized and saved: resize_train_org\org_ecg_234_1320.png
# Resized and saved: resize_train_org\org_ecg_234_1330.png
# Resized and saved: resize_train_org\org_ecg_234_1340.png
# Resized and saved: resize_train_org\org_ecg_234_1350.png
# Resized and saved: resize_train_org\org_ecg_234_1360.png
# Resized and saved: resize_train_org\org_ecg_234_1370.png
# Resized and saved: resize_train_org\org_ecg_234_1380.png
# Resized and saved: resize_train_org\org_ecg_234_1390.png
# Resized and saved: resize_train_org\org_ecg_234_140.png
# Resized and saved: resize_train_org\org_ecg_234_1400.png
# Resized and saved: resize_train_org\org_ecg_234_1410.png
# Resized and saved: resize_train_org\org_ecg_234_1420.png
# Resized and saved: resize_train_org\org_ecg_234_1430.png
# Resized and saved: resize_train_org\org_ecg_234_1440.png
# Resized and saved: resize_train_org\org_ecg_234_1450.png
# Resized and saved: resize_train_org\org_ecg_234_1460.png
# Resized and saved: resize_train_org\org_ecg_234_1470.png
# Resized and saved: resize_train_org\org_ecg_234_1480.png
# Resized and saved: resize_train_org\org_ecg_234_1490.png
# Resized and saved: resize_train_org\org_ecg_234_150.png
# Resized and saved: resize_train_org\org_ecg_234_1500.png
# Resized and saved: resize_train_org\org_ecg_234_1510.png
# Resized and saved: resize_train_org\org_ecg_234_1520.png
# Resized and saved: resize_train_org\org_ecg_234_1530.png
# Resized and saved: resize_train_org\org_ecg_234_1540.png
# Resized and saved: resize_train_org\org_ecg_234_1550.png
# Resized and saved: resize_train_org\org_ecg_234_1560.png
# Resized and saved: resize_train_org\org_ecg_234_1570.png
# Resized and saved: resize_train_org\org_ecg_234_1580.png
# Resized and saved: resize_train_org\org_ecg_234_1590.png
# Resized and saved: resize_train_org\org_ecg_234_160.png
# Resized and saved: resize_train_org\org_ecg_234_1600.png
# Resized and saved: resize_train_org\org_ecg_234_1610.png
# Resized and saved: resize_train_org\org_ecg_234_1620.png
# Resized and saved: resize_train_org\org_ecg_234_1630.png
# Resized and saved: resize_train_org\org_ecg_234_1640.png
# Resized and saved: resize_train_org\org_ecg_234_1650.png
# Resized and saved: resize_train_org\org_ecg_234_1660.png
# Resized and saved: resize_train_org\org_ecg_234_1670.png
# Resized and saved: resize_train_org\org_ecg_234_1680.png
# Resized and saved: resize_train_org\org_ecg_234_1690.png
# Resized and saved: resize_train_org\org_ecg_234_170.png
# Resized and saved: resize_train_org\org_ecg_234_1700.png
# Resized and saved: resize_train_org\org_ecg_234_1710.png
# Resized and saved: resize_train_org\org_ecg_234_1720.png
# Resized and saved: resize_train_org\org_ecg_234_1730.png
# Resized and saved: resize_train_org\org_ecg_234_1740.png
# Resized and saved: resize_train_org\org_ecg_234_1750.png
# Resized and saved: resize_train_org\org_ecg_234_1760.png
# Resized and saved: resize_train_org\org_ecg_234_1770.png
# Resized and saved: resize_train_org\org_ecg_234_1780.png
# Resized and saved: resize_train_org\org_ecg_234_1790.png
# Resized and saved: resize_train_org\org_ecg_234_180.png
# Resized and saved: resize_train_org\org_ecg_234_1800.png
# Resized and saved: resize_train_org\org_ecg_234_190.png
# Resized and saved: resize_train_org\org_ecg_234_20.png
# Resized and saved: resize_train_org\org_ecg_234_200.png
# Resized and saved: resize_train_org\org_ecg_234_210.png
# Resized and saved: resize_train_org\org_ecg_234_220.png
# Resized and saved: resize_train_org\org_ecg_234_230.png
# Resized and saved: resize_train_org\org_ecg_234_240.png
# Resized and saved: resize_train_org\org_ecg_234_250.png
# Resized and saved: resize_train_org\org_ecg_234_260.png
# Resized and saved: resize_train_org\org_ecg_234_270.png
# Resized and saved: resize_train_org\org_ecg_234_280.png
# Resized and saved: resize_train_org\org_ecg_234_290.png
# Resized and saved: resize_train_org\org_ecg_234_30.png
# Resized and saved: resize_train_org\org_ecg_234_300.png
# Resized and saved: resize_train_org\org_ecg_234_310.png
# Resized and saved: resize_train_org\org_ecg_234_320.png
# Resized and saved: resize_train_org\org_ecg_234_330.png
# Resized and saved: resize_train_org\org_ecg_234_340.png
# Resized and saved: resize_train_org\org_ecg_234_350.png
# Resized and saved: resize_train_org\org_ecg_234_360.png
# Resized and saved: resize_train_org\org_ecg_234_370.png
# Resized and saved: resize_train_org\org_ecg_234_380.png
# Resized and saved: resize_train_org\org_ecg_234_390.png
# Resized and saved: resize_train_org\org_ecg_234_40.png
# Resized and saved: resize_train_org\org_ecg_234_400.png
# Resized and saved: resize_train_org\org_ecg_234_410.png
# Resized and saved: resize_train_org\org_ecg_234_420.png
# Resized and saved: resize_train_org\org_ecg_234_430.png
# Resized and saved: resize_train_org\org_ecg_234_440.png
# Resized and saved: resize_train_org\org_ecg_234_450.png
# Resized and saved: resize_train_org\org_ecg_234_460.png
# Resized and saved: resize_train_org\org_ecg_234_470.png
# Resized and saved: resize_train_org\org_ecg_234_480.png
# Resized and saved: resize_train_org\org_ecg_234_490.png
# Resized and saved: resize_train_org\org_ecg_234_50.png
# Resized and saved: resize_train_org\org_ecg_234_500.png
# Resized and saved: resize_train_org\org_ecg_234_510.png
# Resized and saved: resize_train_org\org_ecg_234_520.png
# Resized and saved: resize_train_org\org_ecg_234_530.png
# Resized and saved: resize_train_org\org_ecg_234_540.png
# Resized and saved: resize_train_org\org_ecg_234_550.png
# Resized and saved: resize_train_org\org_ecg_234_560.png
# Resized and saved: resize_train_org\org_ecg_234_570.png
# Resized and saved: resize_train_org\org_ecg_234_580.png
# Resized and saved: resize_train_org\org_ecg_234_590.png
# Resized and saved: resize_train_org\org_ecg_234_60.png
# Resized and saved: resize_train_org\org_ecg_234_600.png
# Resized and saved: resize_train_org\org_ecg_234_610.png
# Resized and saved: resize_train_org\org_ecg_234_620.png
# Resized and saved: resize_train_org\org_ecg_234_630.png
# Resized and saved: resize_train_org\org_ecg_234_640.png
# Resized and saved: resize_train_org\org_ecg_234_650.png
# Resized and saved: resize_train_org\org_ecg_234_660.png
# Resized and saved: resize_train_org\org_ecg_234_670.png
# Resized and saved: resize_train_org\org_ecg_234_680.png
# Resized and saved: resize_train_org\org_ecg_234_690.png
# Resized and saved: resize_train_org\org_ecg_234_70.png
# Resized and saved: resize_train_org\org_ecg_234_700.png
# Resized and saved: resize_train_org\org_ecg_234_710.png
# Resized and saved: resize_train_org\org_ecg_234_720.png
# Resized and saved: resize_train_org\org_ecg_234_730.png
# Resized and saved: resize_train_org\org_ecg_234_740.png
# Resized and saved: resize_train_org\org_ecg_234_750.png
# Resized and saved: resize_train_org\org_ecg_234_760.png
# Resized and saved: resize_train_org\org_ecg_234_770.png
# Resized and saved: resize_train_org\org_ecg_234_780.png
# Resized and saved: resize_train_org\org_ecg_234_790.png
# Resized and saved: resize_train_org\org_ecg_234_80.png
# Resized and saved: resize_train_org\org_ecg_234_800.png
# Resized and saved: resize_train_org\org_ecg_234_810.png
# Resized and saved: resize_train_org\org_ecg_234_820.png
# Resized and saved: resize_train_org\org_ecg_234_830.png
# Resized and saved: resize_train_org\org_ecg_234_840.png
# Resized and saved: resize_train_org\org_ecg_234_850.png
# Resized and saved: resize_train_org\org_ecg_234_860.png
# Resized and saved: resize_train_org\org_ecg_234_870.png
# Resized and saved: resize_train_org\org_ecg_234_880.png
# Resized and saved: resize_train_org\org_ecg_234_890.png
# Resized and saved: resize_train_org\org_ecg_234_90.png
# Resized and saved: resize_train_org\org_ecg_234_900.png
# Resized and saved: resize_train_org\org_ecg_234_910.png
# Resized and saved: resize_train_org\org_ecg_234_920.png
# Resized and saved: resize_train_org\org_ecg_234_930.png
# Resized and saved: resize_train_org\org_ecg_234_940.png
# Resized and saved: resize_train_org\org_ecg_234_950.png
# Resized and saved: resize_train_org\org_ecg_234_960.png
# Resized and saved: resize_train_org\org_ecg_234_970.png
# Resized and saved: resize_train_org\org_ecg_234_980.png
# Resized and saved: resize_train_org\org_ecg_234_990.png
# Done resizing all images.
